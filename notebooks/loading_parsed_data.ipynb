# %%
import pandas as pd

# %%
movies_info = pd.read_parquet("../data/movies.parquet")
movies_info.shape
# Out:
# (984, 43)

# %%
movie_reviews_info = pd.read_parquet("../data/reviews.parquet")
movie_reviews_info.shape
# Out:
# (171094, 10)

# %%
movies_info.head()
# Out:
#        id                    russian_title              original_title  \
# 0  535341                       1+1 (2011)                Intouchables
# 1   11130  10 причин моей ненависти (1999)  10 Things I Hate About You
# 2  606646            12 лет рабства (2013)            12 Years a Slave
# 3     502                12 обезьян (1995)              Twelve Monkeys
# 4     346    12 разгневанных мужчин (1956)                12 Angry Men
#
#                                               actors  \
# 0  [Франсуа Клюзе, Омар Си, Анн Ле Ни, Одри Флеро...
# 1  [Хит Леджер, Джулия Стайлз, Джозеф Гордон-Леви...
# 2  [Чиветель Эджиофор, Майкл Фассбендер, Лупита Н...
# 3  [Брюс Уиллис, Мэделин Стоу, Брэд Питт, Кристоф...
# 4  [Генри Фонда, Мартин Болсам, Ли Дж. Кобб, Джоз...
#
#                                         voice_actors  year  \
# 0  [Владимир Зайцев, Илья Исаев, Елена Соловьева,...  2011
# 1                                                 []  1999
# ...

# %%
series_info = pd.read_parquet("../data/series.parquet")
series_info.shape
# Out:
# (978, 43)

# %%
series_review_info = pd.read_parquet("../data/series_reviews.parquet")
series_review_info.shape
# Out:
# (35643, 10)

# %%
series_info.sample(5)
# Out:
#           id                          russian_title original_title  \
# 277  1112061    За первого встречного (сериал 2019)
# 238   408655       Ди.Грэй-мен (сериал 2006 – 2008)     D.Gray-man
# 702  1254370                 Рагнарёк (сериал 2020)       Ragnarok
# 850  1311936  Трудные подростки (сериал 2019 – ...)
# 420   996399   Лучше, чем люди (сериал 2018 – 2019)
#
#                                                 actors voice_actors  \
# 277  [Равшана Куркова, Александр Пашков, Наталья Но...           []
# 238  [Санаэ Кобаяси, Сидзука Ито, Кэнъити Судзумура...           []
# 702  [Давид Александр Шохолт, Йонас Страндт Гравли,...           []
# 850  [Никита Волков, Виталий Андреев, Анастасия Кры...           []
# 420  [Паулина Андреева, Кирилл Кяро, Александр Устю...           []
#
#                 year country                                        genre  \
# 277   2019 (1 сезон)  Россия                                    мелодрама
# ...

# %%
series_review_info.sample(5)
# Out:
#        movie_id  review_id              username                datetime  \
# 238      582358    1094539         rinatkhamatov    08 апреля 2017 16:30
# 10890     77043      90903             Ladynelly   26 октября 2014 15:27
# 9746    1112955   59418160  maryaswon@rambler.ru  18 сентября 2021 09:18
# 26508     89540      10261               Badmozg    11 апреля 2007 14:36
# 1606     589167    1007150              Eri-Asai   31 октября 2011 19:50
#
#       sentiment                                           subtitle  \
# 238        good
# 10890      good                     Зачарованный кусочек юности...
# 9746       good  «Доктор Хэрроу» - та же «Вечность», но без фан...
# 26508   neutral
# 1606       good                                      Зло в подвале
#
#                                              review_body    score  \
# 238    Романтика этого сериала (конкретно 1-ого сезон...
# 10890  Этот сериал вошел в мою жизнь лет в 18-19... Т...
# ...
