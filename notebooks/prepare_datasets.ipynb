# %% [markdown]
# # Datasets preparation

# %% [markdown]
# In this notebook I'm going to prepare datasets for storing in their own repository.

# %% [markdown]
# ## Imports

# %%
import os
from pathlib import Path

import pandas as pd

# %%
SEED = 42

# %% [markdown]
# ## Paths

# %%
RELATIVE_PATH = os.path.join("../", "data")
INFO_PATH = os.path.join(RELATIVE_PATH, "1_anonymized_data")
CLEANED_REVIEWS_PATH = os.path.join(RELATIVE_PATH, "2_cleaned_reviews")
CLEANED_DATASETS_PATH = os.path.join(RELATIVE_PATH, "2_cleaned_datasets")

# %%
Path(CLEANED_DATASETS_PATH).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Loading reviews

# %%
reviews = pd.read_parquet(os.path.join(CLEANED_REVIEWS_PATH, "reviews.parquet"))
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206537 entries, 0 to 206536
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   show_id       206537 non-null  int64
#  1   user_id       206537 non-null  int64
#  2   type          206537 non-null  category
#  3   datetime      206537 non-null  datetime64[ns]
#  4   sentiment     206537 non-null  category
#  5   subtitle      173664 non-null  object
#  6   review        206537 non-null  object
#  7   review_score  206537 non-null  int64
#  8   score         129216 non-null  float64
# dtypes: category(2), datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 11.4+ MB

# %% [markdown]
# ### Loading movies info

# %%
movies_info = pd.read_parquet(os.path.join(INFO_PATH, "movies_info.parquet"))
movies_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 43 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 984 non-null    int64
#  1   russian_title                      984 non-null    object
#  2   original_title                     984 non-null    object
#  3   actors                             984 non-null    object
#  4   voice_actors                       984 non-null    object
#  5   year                               984 non-null    object
#  6   country                            984 non-null    object
#  7   genre                              984 non-null    object
#  8   slogan                             984 non-null    object
#  9   director                           984 non-null    object
#  10  scriptwriter                       984 non-null    object
#  11  producer                           984 non-null    object
#  12  operator                           984 non-null    object
#  13  composer                           984 non-null    object
#  14  artist                             984 non-null    object
#  15  cut                                984 non-null    object
#  16  budget                             984 non-null    object
#  17  us_box_office                      984 non-null    object
#  18  world_box_office                   984 non-null    object
#  19  viewers                            984 non-null    object
#  20  russian_box_office                 984 non-null    object
#  21  russian_premiere                   984 non-null    object
#  22  world_premiere                     984 non-null    object
#  23  dvd_release                        984 non-null    object
#  24  blue_ray_release                   984 non-null    object
#  25  age_rating                         984 non-null    object
#  26  mpaa_rating                        984 non-null    object
#  27  duration                           984 non-null    object
#  28  digital_release                    984 non-null    object
#  29  marketing                          984 non-null    object
#  30  platform                           984 non-null    object
#  31  rerelease                          984 non-null    object
#  32  film_director                      984 non-null    object
#  33  rating_kinopoisk                   984 non-null    object
#  34  rating_count_kinopoisk             984 non-null    object
#  35  rating_imdb                        984 non-null    object
#  36  rating_count_imdb                  984 non-null    object
#  37  synopsis                           984 non-null    object
#  38  world_critics_percentage           984 non-null    object
#  39  world_critics_star_value           984 non-null    object
#  40  world_critics_number_of_reviews    984 non-null    object
#  41  russian_critics_percentage         984 non-null    object
#  42  russian_critics_number_of_reviews  984 non-null    object
# dtypes: int64(1), object(42)
# memory usage: 330.7+ KB

# %% [markdown]
# ### Loading series info

# %%
series_info = pd.read_parquet(os.path.join(INFO_PATH, "series_info.parquet"))
series_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 40 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 980 non-null    int64
#  1   russian_title                      980 non-null    object
#  2   original_title                     980 non-null    object
#  3   actors                             980 non-null    object
#  4   voice_actors                       980 non-null    object
#  5   year                               980 non-null    object
#  6   country                            980 non-null    object
#  7   genre                              980 non-null    object
#  8   slogan                             980 non-null    object
#  9   director                           980 non-null    object
#  10  scriptwriter                       980 non-null    object
#  11  producer                           980 non-null    object
#  12  operator                           980 non-null    object
#  13  composer                           980 non-null    object
#  14  artist                             980 non-null    object
#  15  cut                                980 non-null    object
#  16  budget                             980 non-null    object
#  17  us_box_office                      980 non-null    object
#  18  world_box_office                   980 non-null    object
#  19  russian_box_office                 980 non-null    object
#  20  russian_premiere                   980 non-null    object
#  21  world_premiere                     980 non-null    object
#  22  dvd_release                        980 non-null    object
#  23  blue_ray_release                   980 non-null    object
#  24  age_rating                         980 non-null    object
#  25  mpaa_rating                        980 non-null    object
#  26  duration                           980 non-null    object
#  27  digital_release                    980 non-null    object
#  28  platform                           980 non-null    object
#  29  film_director                      980 non-null    object
#  30  rating_kinopoisk                   980 non-null    object
#  31  rating_count_kinopoisk             980 non-null    object
#  32  rating_imdb                        980 non-null    object
#  33  rating_count_imdb                  980 non-null    object
#  34  synopsis                           980 non-null    object
#  35  world_critics_percentage           980 non-null    object
#  36  world_critics_star_value           980 non-null    object
#  37  world_critics_number_of_reviews    980 non-null    object
#  38  russian_critics_percentage         980 non-null    object
#  39  russian_critics_number_of_reviews  980 non-null    object
# dtypes: int64(1), object(39)
# memory usage: 306.4+ KB

# %% [markdown]
# ### Datasets overview

# %%
reviews.sample(n=10)
# Out:
#         show_id  user_id    type            datetime sentiment  \
# 70216       440    34149   movie 2012-08-11 17:49:00  negative
# 124929      731    51085   movie 2018-07-22 11:40:00  positive
# 168926      595    60239   movie 2012-09-24 22:54:00  positive
# 114347      919    41008   movie 2016-02-28 21:42:00  positive
# 82961       408    36526   movie 2009-11-02 18:02:00   neutral
# 181186     1073    34835  series 2017-09-23 07:26:00  positive
# 86602       329    31593   movie 2017-04-12 20:16:00  positive
# 199707      788    29396  series 2017-11-12 12:56:00  positive
# 16907        84    17991   movie 2013-08-15 20:25:00  positive
# 53721       219    42553   movie 2010-02-06 12:06:00  positive
#
#                                                  subtitle  \
# 70216                                                None
# 124929               'Найти темное место и все исправить'
# 168926                               Причем тут Ирландия?
# 114347                  Скандал, который скрывала Церковь
# 82961                               Иллюзия безнадёжности
# 181186              И вернулись они в свой отчий берег...
# 86602   «Не клади в карман эту монетку, это твоя счаст...
# 199707  «Моя жизнь — это толчок с говном, с которым ни...
# 16907                                     Вера в человека
# 53721               Скажу честно: я... - Железный Человек
#
#                                                    review  review_score  score
# 70216   Еще до выхода фильма я довольно часто слышал о...             1    NaN
# 124929  Фильм замечательный, глубокий и философский, и...             0   10.0
# 168926  Лично я никакого колорита не усмотрел. Просто ...             5   10.0
# 494                      США                     биография, спорт, драма
#
#                                                 slogan  \
# 613                           «Она изменит вашу жизнь»
# 451       «Он в прямом эфире и даже не подозревает...»
# 731
# 436  «From the smallest beginnings come the greates...
# 275
# 582                            «Умереть, чтобы выжить»
# 707  «The true story of a woman who defied a nation...
# 299                                   «Уйдем по небу!»
# 718                      «Жизнь — лишь вопрос времени»
# 494                         «А что в жизни сделал ты?»
#
#                                director  ... rating_kinopoisk  \
# 613                       Жан-Пьер Жёне  ...              8.0
# 451                           Питер Уир  ...              8.3
# 731                       Клод Ланзманн  ...              8.0
# 436                       Питер Джексон  ...              8.1
# 275                       Петер Торварт  ...              6.2
# 582                         Джон Хаддлс  ...              5.8
# 707                         Ридли Скотт  ...              7.4
# 299  Тимур Бекмамбетов, Сергей Трофимов  ...              6.3
# 718                    М. Найт Шьямалан  ...              6.4
# 494                      Беннетт Миллер  ...              7.7
#
#     rating_count_kinopoisk rating_imdb rating_count_imdb  \
# 613         273 820 оценок  IMDb: 8.30    741 208 оценок
# 451         405 527 оценок  IMDb: 8.20  1 028 992 оценки
# 731           2 936 оценок  IMDb: 8.70      9 350 оценок
# 436         444 968 оценок  IMDb: 7.80    800 956 оценок
# 275          15 678 оценок  IMDb: 6.10     45 493 оценки
# 582          58 176 оценок  IMDb: 5.60     22 295 оценок
# 707          69 224 оценки  IMDb: 7.40    138 347 оценок
# 299          55 938 оценок  IMDb: 5.60        486 оценок
# 718         220 339 оценок  IMDb: 5.80     93 365 оценок
# 494         143 275 оценок  IMDb: 7.60    409 846 оценок
#
#                                               synopsis  \
# 613  Знаете ли вы, что все события, происходящие в ...
# 451  Представьте себе, что вы вдруг начинаете поним...
# 731  Документальный фильм, рассказывающий о массово...
# 436  Хоббит Бильбо Бэггинс пускается в грандиозный ...
# 275  Надя с восьмилетним сыном летит в Штаты, где е...
# 582  В международной школе в Джакарте таинственный ...
# 707  Франция, конец XIV века. Отношения между рыцар...
# 299  Лето 1944 года. Советские войска ведут наступл...
# 718  Отправившись в отпуск на тропический остров, с...
# 494  Фильм по книге Майкла M. Льюиса, изданной в 20...
#
#     world_critics_percentage world_critics_star_value  \
# 613                      89%                      8.1
# 451                      95%                      8.4
# 731                     100%                      9.2
# 436                      64%                      6.5
# 275                      80%                      6.5
# 582                      67%                      5.6
# 707                      85%                      7.3
# 299
# 718                      50%                      5.6
# 494                      94%                        8
#
#     world_critics_number_of_reviews russian_critics_percentage  \
# 613                      185 оценок                       100%
# 451                      134 оценки
# 731                       37 оценок                       100%
# 436                      305 оценок                        90%
# 275                       30 оценок                        60%
# 582                       15 оценок                          –
# 707                      281 оценка                        93%
# 299
# 718                      332 оценки                        33%
# 494                      268 оценок                       100%
#
#     russian_critics_number_of_reviews
# 613                          8 оценок
# 451
# 731                          3 оценки
# 436                         30 оценок
# 275                          5 оценок
# 582                          2 оценки
# 707                         14 оценок
# 299
# 718                         12 оценок
# 494                          7 оценок
#
# [10 rows x 43 columns]

# %%
series_info.sample(n=10, random_state=SEED)
# Out:
# 852                                     Тим Киркби  ...
# 405                                 Эмре Кабакушак  ...              6.6
# 736    Брайан Тейлор, Уэйн Йип, Марианна Пока, ...  ...              7.6
# 457               Стивен Содерберг, Барри Дженкинс  ...              8.4
# 307         Ким Со-ён, Аня Адамс, Лиз Флэхайв, ...  ...              5.9
#
#     rating_count_kinopoisk rating_imdb rating_count_imdb  \
# 788          79 312 оценок  IMDb: 8.50      7 024 оценки
# 440          78 973 оценки  IMDb: 8.30        331 оценка
# 139         102 287 оценок  IMDb: 7.60    293 539 оценок
# 695           4 343 оценки  IMDb: 8.80     51 474 оценки
# 66          157 119 оценок  IMDb: 6.10      3 095 оценок
# 852                         IMDb: 6.10      4 578 оценок
# 405           6 414 оценок  IMDb: 5.70      2 223 оценки
# 736          14 103 оценки  IMDb: 8.10     37 838 оценок
# 457          36 863 оценки  IMDb: 8.50     47 745 оценок
# 307             386 оценок  IMDb: 5.30      1 688 оценок
#
#                                               synopsis  \
# 788  Будни Адама, ординатора родильного отделения г...
# 440  Уникальный по форме проект, приуроченным к  40...
# 139  В центре событий — молодая женщина-хирург Мере...
# 695  XIX век. Семья Даттон пытается спастись от нищ...
# 66   Зик Райдер – озорной десятилетний мальчик, тал...
# 852  «Пентаверат» — это секретное общество, состоящ...
# 405  Молодые люди Санджар и Нарэ безумно полюбили д...
# 736  Ник Сакс, вечно пьяный бывший полицейский, ста...
# 457  Доктор Джон Тэкери работает хирургом в нью-йор...
# 307  Восемь феминистских историй с неожиданными взг...
#
#     world_critics_percentage world_critics_star_value  \
# 788
# 440
# 139
# 695
# 66
# 852
# 405
# 736
# 457
# 307
#
#     world_critics_number_of_reviews russian_critics_percentage  \
# 788
# 440
# 139
# 695
# 66
# 852
# 405
# 736
# 457
# 307
#
#     russian_critics_number_of_reviews
# 788
# 440
# 139
# 695
# 66
# 852
# 405
# 736
# 457
# 307
#
# [10 rows x 40 columns]

# %% [markdown]
# ## Processing

# %%
set(series_info.columns).issubset(set(movies_info.columns))
# Out:
# True

# %% [markdown]
# We know that the columns in `series_info` dataframe are the subset of columns from the `movies_info` dataframe.

# %%
set(movies_info.columns) - set(series_info.columns)
# Out:
# {'marketing', 'rerelease', 'viewers'}

# %% [markdown]
# `movies_info` dataframe has 3 additional columns: `marketing`, `rerelease` and `viewers`.

# %% [markdown]
# Let's merge two dataframes together.

# %%
movies_info.insert(1, "type", "movie")
series_info.insert(1, "type", "series")

# %%
info = pd.concat([movies_info, series_info])

# %% [markdown]
# ## Saving

# %% [markdown]
# ### Reviews

# %% [markdown]
# For dataset with reviews I'm going to save two versions: short (only `sentiment`, `review` and `show_id` for stratification) and full (all columns).

# %%
reviews[["show_id", "sentiment", "review"]].to_parquet(
    os.path.join(CLEANED_DATASETS_PATH, "reviews_short.parquet"), index=False
)

# %%
reviews.to_parquet(
    os.path.join(CLEANED_DATASETS_PATH, "reviews_full.parquet"), index=False
)

# %% [markdown]
# ### Info

# %%
info.to_parquet(os.path.join(CLEANED_DATASETS_PATH, "info.parquet"), index=False)
