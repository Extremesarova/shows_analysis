# %%
import pandas as pd

# %%
movies_info = pd.read_parquet("../data/raw_movies_info.parquet")
movies_info.shape
# Out:
# (984, 43)

# %%
movie_reviews_info = pd.read_parquet("../data/raw_movies_reviews.parquet")
movie_reviews_info.shape
# Out:
# (171094, 8)

# %%
movies_info.head()
# Out:
#        id                    russian_title              original_title  \
# 0  535341                       1+1 (2011)                Intouchables
# 1   11130  10 причин моей ненависти (1999)  10 Things I Hate About You
# 2  606646            12 лет рабства (2013)            12 Years a Slave
# 3     502                12 обезьян (1995)              Twelve Monkeys
# 4     346    12 разгневанных мужчин (1956)                12 Angry Men
#
#                                               actors  \
# 0  [Франсуа Клюзе, Омар Си, Анн Ле Ни, Одри Флеро...
# 1  [Хит Леджер, Джулия Стайлз, Джозеф Гордон-Леви...
# 2  [Чиветель Эджиофор, Майкл Фассбендер, Лупита Н...
# 3  [Брюс Уиллис, Мэделин Стоу, Брэд Питт, Кристоф...
# 4  [Генри Фонда, Мартин Болсам, Ли Дж. Кобб, Джоз...
#
#                                         voice_actors  year  \
# 0  [Владимир Зайцев, Илья Исаев, Елена Соловьева,...  2011
# 1                                                 []  1999
# ...

# %%
series_info = pd.read_parquet("../data/raw_series_info.parquet")
series_info.shape
# Out:
# (978, 40)

# %%
series_review_info = pd.read_parquet("../data/raw_series_reviews.parquet")
series_review_info.shape
# Out:
# (35643, 8)

# %%
series_info.sample(5)
# Out:
#           id                                      russian_title  \
# 40   1174294                       Амфибия (сериал 2019 – 2022)
# 644  1044770  Полицейский с Рублёвки в Бескудниково (сериал ...
# 663  1197956               Почему женщины убивают (сериал 2019)
# 212   817942             Два лица Стамбула (сериал 2013 – 2014)
# 167   602284             Время приключений (сериал 2010 – 2018)
#
#                       original_title  \
# 40                          Amphibia
# 644
# 663                   Why Women Kill
# 212                    Fatih Harbiye
# 167  Adventure Time with Finn & Jake
#
#                                                 actors  \
# 40   [Бренда Сонг, Джастин Фелбингер, Билл Фармер, ...
# 644  [Александр Петров, Сергей Бурунов, Татьяна Баб...
# 663  [Люси Лью, Джек Девенпорт, Эллисон Толман, Джи...
# 212  [Кадир Догулу, Неслихан Атагюль, Серкан Шеналп...
# 167  [Джон Ди Маджио, Джереми Шэда, Том Кенни, Хинд...
#
# ...

# %%
series_review_info.sample(5)
# Out:
#        show_id     username               datetime sentiment  \
# 20434   585595  Baobabochka     02 июля 2012 10:51       bad
# 12381   501998      StLight  09 декабря 2011 01:31      good
# 7159    412342  belek10lsch     07 июля 2011 15:37      good
# 31650   557806      Hiltguy  20 августа 2016 03:32      good
# 4054   1044004     softland  29 декабря 2019 13:09       bad
#
#                                              subtitle  \
# 20434
# 12381                          За работу живодеры!(c)
# 7159                               'How wonderful...'
# 31650  'Нанося удар, убедись, что отправишь в нокаут'
# 4054                                 Из грязи в грязь
#
#                                              review_body usefulness_ratio  \
# 20434  Начала смотреть этот сериал, потому что идея п...         65 / 123
# 12381  Посмотрев все сезоны 'Интернов', хочу сказать,...           12 / 5
# 7159   Когда слышишь слово 'сериал' не всегда у тебя ...           24 / 3
# ...
